# %% [markdown]
# Healthcare data cleaning

# %%
import pandas as pd
import numpy as np
import base64
from IPython.display import HTML

# %%
df = pd.read_csv('../datasets/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
print(df.columns)
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# Here is the head of the data set, followed by the name of the columns, I have done this to see what I am working with

# %%
df.isna().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %% [markdown]
# Here I have checked for any null cells in the data set

# %%
# Check for duplicate rows
duplicates = df.duplicated()
print("Number of duplicate rows:", duplicates.sum())

# Optionally, display the duplicate rows
df[duplicates]
# Out:
# Number of duplicate rows: 1
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %% [markdown]
# Here I have checked for any duplcated rows in the dataset, as is likely to be a duplicated row

# %%
df = df.drop_duplicates()
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %% [markdown]
# Here I have dropped the duplicated row

# %%
# Add new empty columns to the DataFrame
df['bmi range'] = np.nan
df['age range'] = np.nan
df['family status'] = np.nan

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges  bmi range  \
# 0      19  female  27.900         0    yes  southwest  16884.92400        NaN
# 1      18    male  33.770         1     no  southeast   1725.55230        NaN
# 2      28    male  33.000         3     no  southeast   4449.46200        NaN
# 3      33    male  22.705         0     no  northwest  21984.47061        NaN
# 4      32    male  28.880         0     no  northwest   3866.85520        NaN
# ...   ...     ...     ...       ...    ...        ...          ...        ...
# 1333   50    male  30.970         3     no  northwest  10600.54830        NaN
# 1334   18  female  31.920         0     no  northeast   2205.98080        NaN
# 1335   18  female  36.850         0     no  southeast   1629.83350        NaN
# 1336   21  female  25.800         0     no  southwest   2007.94500        NaN
# 1337   61  female  29.070         0    yes  northwest  29141.36030        NaN
#
#       age range  family status
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
# ...         ...            ...
# 1333        NaN            NaN
# 1334        NaN            NaN
# 1335        NaN            NaN
# 1336        NaN            NaN
# 1337        NaN            NaN
#
# [1337 rows x 10 columns]

# %%
df = df[['age', 'age range', 'sex', 'bmi', 'bmi range', 'children', 'family status', 'smoker', 'region', 'charges']]
df
# Out:
#       age  age range     sex     bmi  bmi range  children  family status  \
# 0      19        NaN  female  27.900        NaN         0            NaN
# 1      18        NaN    male  33.770        NaN         1            NaN
# 2      28        NaN    male  33.000        NaN         3            NaN
# 3      33        NaN    male  22.705        NaN         0            NaN
# 4      32        NaN    male  28.880        NaN         0            NaN
# ...   ...        ...     ...     ...        ...       ...            ...
# 1333   50        NaN    male  30.970        NaN         3            NaN
# 1334   18        NaN  female  31.920        NaN         0            NaN
# 1335   18        NaN  female  36.850        NaN         0            NaN
# 1336   21        NaN  female  25.800        NaN         0            NaN
# 1337   61        NaN  female  29.070        NaN         0            NaN
#
#      smoker     region      charges
# 0       yes  southwest  16884.92400
# 1        no  southeast   1725.55230
# 2        no  southeast   4449.46200
# 3        no  northwest  21984.47061
# 4        no  northwest   3866.85520
# ...     ...        ...          ...
# 1333     no  northwest  10600.54830
# 1334     no  northeast   2205.98080
# 1335     no  southeast   1629.83350
# 1336     no  southwest   2007.94500
# 1337    yes  northwest  29141.36030
#
# [1337 rows x 10 columns]

# %% [markdown]
# Here I have organised the columns.

# %%
 # Assign BMI range using pd.cut
df['bmi range'] = pd.cut(
    df['bmi'],
    bins=[-float('inf'), 18.5, 24.9, 29.9, float('inf')],
    labels=['underweight', 'normal weight', 'overweight', 'obesity']
)

# %%
df
# Out:
#       age  age range     sex     bmi      bmi range  children  family status  \
# 0      19        NaN  female  27.900     overweight         0            NaN
# 1      18        NaN    male  33.770        obesity         1            NaN
# 2      28        NaN    male  33.000        obesity         3            NaN
# 3      33        NaN    male  22.705  normal weight         0            NaN
# 4      32        NaN    male  28.880     overweight         0            NaN
# ...   ...        ...     ...     ...            ...       ...            ...
# 1333   50        NaN    male  30.970        obesity         3            NaN
# 1334   18        NaN  female  31.920        obesity         0            NaN
# 1335   18        NaN  female  36.850        obesity         0            NaN
# 1336   21        NaN  female  25.800     overweight         0            NaN
# 1337   61        NaN  female  29.070     overweight         0            NaN
#
#      smoker     region      charges
# 0       yes  southwest  16884.92400
# 1        no  southeast   1725.55230
# 2        no  southeast   4449.46200
# 3        no  northwest  21984.47061
# 4        no  northwest   3866.85520
# ...     ...        ...          ...
# 1333     no  northwest  10600.54830
# 1334     no  northeast   2205.98080
# 1335     no  southeast   1629.83350
# 1336     no  southwest   2007.94500
# 1337    yes  northwest  29141.36030
#
# [1337 rows x 10 columns]

# %% [markdown]
# Here I have added the BMI range to each person

# %%
for i in df['age']:
    if i < 18:
        df.loc[df['age'] == i, 'age range'] = '0-17'
    elif 18 <= i < 30:
        df.loc[df['age'] == i, 'age range'] = '18-29'
    elif 30 <= i < 45:
        df.loc[df['age'] == i, 'age range'] = '30-44'
    elif 45 <= i < 60:
        df.loc[df['age'] == i, 'age range'] = '45-59'
    else:
        df.loc[df['age'] == i, 'age range'] = '60+'
# Out:
# C:\Users\matte\AppData\Local\Temp\ipykernel_15256\2908488889.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18-29' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['age'] == i, 'age range'] = '18-29'

# %%
df
# Out:
#       age age range     sex     bmi      bmi range  children  family status  \
# 0      19     18-29  female  27.900     overweight         0            NaN
# 1      18     18-29    male  33.770        obesity         1            NaN
# 2      28     18-29    male  33.000        obesity         3            NaN
# 3      33     30-44    male  22.705  normal weight         0            NaN
# 4      32     30-44    male  28.880     overweight         0            NaN
# ...   ...       ...     ...     ...            ...       ...            ...
# 1333   50     45-59    male  30.970        obesity         3            NaN
# 1334   18     18-29  female  31.920        obesity         0            NaN
# 1335   18     18-29  female  36.850        obesity         0            NaN
# 1336   21     18-29  female  25.800     overweight         0            NaN
# 1337   61       60+  female  29.070     overweight         0            NaN
#
#      smoker     region      charges
# 0       yes  southwest  16884.92400
# 1        no  southeast   1725.55230
# 2        no  southeast   4449.46200
# 3        no  northwest  21984.47061
# 4        no  northwest   3866.85520
# ...     ...        ...          ...
# 1333     no  northwest  10600.54830
# 1334     no  northeast   2205.98080
# 1335     no  southeast   1629.83350
# 1336     no  southwest   2007.94500
# 1337    yes  northwest  29141.36030
#
# [1337 rows x 10 columns]

# %% [markdown]
# Here I have added age ranges to each person

# %%
for i in df['children']:
    if i == 0:
        df.loc[df['children'] == i, 'family status'] = 'no children'
    else:
        df.loc[df['children'] == i, 'family status'] = 'has children'
# Out:
# C:\Users\matte\AppData\Local\Temp\ipykernel_15256\3155237786.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'no children' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['children'] == i, 'family status'] = 'no children'

# %%
df
# Out:
#       age age range     sex     bmi      bmi range  children family status  \
# 0      19     18-29  female  27.900     overweight         0   no children
# 1      18     18-29    male  33.770        obesity         1  has children
# 2      28     18-29    male  33.000        obesity         3  has children
# 3      33     30-44    male  22.705  normal weight         0   no children
# 4      32     30-44    male  28.880     overweight         0   no children
# ...   ...       ...     ...     ...            ...       ...           ...
# 1333   50     45-59    male  30.970        obesity         3  has children
# 1334   18     18-29  female  31.920        obesity         0   no children
# 1335   18     18-29  female  36.850        obesity         0   no children
# 1336   21     18-29  female  25.800     overweight         0   no children
# 1337   61       60+  female  29.070     overweight         0   no children
#
#      smoker     region      charges
# 0       yes  southwest  16884.92400
# 1        no  southeast   1725.55230
# 2        no  southeast   4449.46200
# 3        no  northwest  21984.47061
# 4        no  northwest   3866.85520
# ...     ...        ...          ...
# 1333     no  northwest  10600.54830
# 1334     no  northeast   2205.98080
# 1335     no  southeast   1629.83350
# 1336     no  southwest   2007.94500
# 1337    yes  northwest  29141.36030
#
# [1337 rows x 10 columns]

# %% [markdown]
# Here I have added a family value to each person

# %%
df['sex'] = df['sex'].str.capitalize()
df['smoker'] = df['smoker'].str.capitalize()
df['region'] = df['region'].str.capitalize()
df['bmi range'] =df['bmi range'].str.capitalize()
df['family status'] = df['family status'].str.title()

# %%
df
# Out:
#       age age range     sex     bmi      bmi range  children family status  \
# 0      19     18-29  Female  27.900     Overweight         0   No Children
# 1      18     18-29    Male  33.770        Obesity         1  Has Children
# 2      28     18-29    Male  33.000        Obesity         3  Has Children
# 3      33     30-44    Male  22.705  Normal weight         0   No Children
# 4      32     30-44    Male  28.880     Overweight         0   No Children
# ...   ...       ...     ...     ...            ...       ...           ...
# 1333   50     45-59    Male  30.970        Obesity         3  Has Children
# 1334   18     18-29  Female  31.920        Obesity         0   No Children
# 1335   18     18-29  Female  36.850        Obesity         0   No Children
# 1336   21     18-29  Female  25.800     Overweight         0   No Children
# 1337   61       60+  Female  29.070     Overweight         0   No Children
#
#      smoker     region      charges
# 0       Yes  Southwest  16884.92400
# 1        No  Southeast   1725.55230
# 2        No  Southeast   4449.46200
# 3        No  Northwest  21984.47061
# 4        No  Northwest   3866.85520
# ...     ...        ...          ...
# 1333     No  Northwest  10600.54830
# 1334     No  Northeast   2205.98080
# 1335     No  Southeast   1629.83350
# 1336     No  Southwest   2007.94500
# 1337    Yes  Northwest  29141.36030
#
# [1337 rows x 10 columns]

# %% [markdown]
# Here I have capitalized the first letter of the values in sex, smoker, and region, for better readability

# %%
df.columns = [col.capitalize() for col in df.columns]

# %%
df
# Out:
#       Age Age range     Sex     Bmi      Bmi range  Children Family status  \
# 0      19     18-29  Female  27.900     Overweight         0   No Children
# 1      18     18-29    Male  33.770        Obesity         1  Has Children
# 2      28     18-29    Male  33.000        Obesity         3  Has Children
# 3      33     30-44    Male  22.705  Normal weight         0   No Children
# 4      32     30-44    Male  28.880     Overweight         0   No Children
# ...   ...       ...     ...     ...            ...       ...           ...
# 1333   50     45-59    Male  30.970        Obesity         3  Has Children
# 1334   18     18-29  Female  31.920        Obesity         0   No Children
# 1335   18     18-29  Female  36.850        Obesity         0   No Children
# 1336   21     18-29  Female  25.800     Overweight         0   No Children
# 1337   61       60+  Female  29.070     Overweight         0   No Children
#
#      Smoker     Region      Charges
# 0       Yes  Southwest  16884.92400
# 1        No  Southeast   1725.55230
# 2        No  Southeast   4449.46200
# 3        No  Northwest  21984.47061
# 4        No  Northwest   3866.85520
# ...     ...        ...          ...
# 1333     No  Northwest  10600.54830
# 1334     No  Northeast   2205.98080
# 1335     No  Southeast   1629.83350
# 1336     No  Southwest   2007.94500
# 1337    Yes  Northwest  29141.36030
#
# [1337 rows x 10 columns]

# %% [markdown]
# Here I have capitalized the column titles

# %%
df['bmi'] = df['Bmi'].round(1)
df['charges'] = df['Charges'].round(2)

# %%
df
# Out:
#       Age Age range     Sex     Bmi      Bmi range  Children Family status  \
# 0      19     18-29  Female  27.900     Overweight         0   No Children
# 1      18     18-29    Male  33.770        Obesity         1  Has Children
# 2      28     18-29    Male  33.000        Obesity         3  Has Children
# 3      33     30-44    Male  22.705  Normal weight         0   No Children
# 4      32     30-44    Male  28.880     Overweight         0   No Children
# ...   ...       ...     ...     ...            ...       ...           ...
# 1333   50     45-59    Male  30.970        Obesity         3  Has Children
# 1334   18     18-29  Female  31.920        Obesity         0   No Children
# 1335   18     18-29  Female  36.850        Obesity         0   No Children
# 1336   21     18-29  Female  25.800     Overweight         0   No Children
# 1337   61       60+  Female  29.070     Overweight         0   No Children
#
#      Smoker     Region      Charges   bmi   charges
# 0       Yes  Southwest  16884.92400  27.9  16884.92
# 1        No  Southeast   1725.55230  33.8   1725.55
# 2        No  Southeast   4449.46200  33.0   4449.46
# 3        No  Northwest  21984.47061  22.7  21984.47
# 4        No  Northwest   3866.85520  28.9   3866.86
# ...     ...        ...          ...   ...       ...
# 1333     No  Northwest  10600.54830  31.0  10600.55
# 1334     No  Northeast   2205.98080  31.9   2205.98
# 1335     No  Southeast   1629.83350  36.8   1629.83
# 1336     No  Southwest   2007.94500  25.8   2007.94
# 1337    Yes  Northwest  29141.36030  29.1  29141.36
#
# [1337 rows x 12 columns]

# %% [markdown]
# Here I have rounded the Bmi for cleanliness, and rounded the charges to make them fit into a monetary value

# %%
def create_download_link(df, title="insurance_cleaned.csv", filename="insurance_cleaned.csv"):
    """Generates a link to download the data in a given pandas DataFrame"""
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload, title=title, filename=filename)
    return HTML(html)
create_download_link(df)
# Out:
# <a download="insurance_cleaned.csv" href="data:text/csv;base64,..." target="_blank">insurance_cleaned.csv</a>

# %% [markdown]
# Here is the cleaned dataset, and a download link for it.
